# %%
import pandas as pd
import numpy as np
obj=pd.Series([2,7,-5,-3])
obj
# Out:
# 0    2
# 1    7
# 2   -5
# 3   -3
# dtype: int64

# %%
obj.array
# Out:
# <PandasArray>
# [2, 7, -5, -3]
# Length: 4, dtype: int64

# %%
obj.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
obj2=pd.Series([2,5,9,11] , index=['a','b','c','d'])
obj2
# Out:
# a     2
# b     5
# c     9
# d    11
# dtype: int64

# %%
obj2.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
obj2['b']
# Out:
# 5

# %%
obj2['b'] = 5

# %%
obj3=pd.Series([3,8,9,10] , index=['neki','asha','anika','roza'])
obj3
# Out:
# neki      3
# asha      8
# anika     9
# roza     10
# dtype: int64

# %%
obj3.index
# Out:
# Index(['neki', 'asha', 'anika', 'roza'], dtype='object')

# %%
obj3['roza']
# Out:
# 10

# %%
obj3['asha'] = 6

# %%
obj3[obj3>2]
# Out:
# neki      3
# asha      6
# anika     9
# roza     10
# dtype: int64

# %%
obj3+2
# Out:
# neki      5
# asha      8
# anika    11
# roza     12
# dtype: int64

# %%
obj3*6
# Out:
# neki     18
# asha     36
# anika    54
# roza     60
# dtype: int64

# %%
sdata={'Colorado':23000 ,'Gregoria':45000 , 'Illinois':14000, 'Nyc':21000}
obj4=pd.Series(sdata)
obj4
# Out:
# Colorado    23000
# Gregoria    45000
# Illinois    14000
# Nyc         21000
# dtype: int64

# %%
obj4.to_dict()
# Out:
# {'Colorado': 23000, 'Gregoria': 45000, 'Illinois': 14000, 'Nyc': 21000}

# %%
state=['colorado','Nyc','Georgia','illinois']
obj5=pd.Series(sdata, index= state)
obj5
# Out:
# colorado        NaN
# Nyc         21000.0
# Georgia         NaN
# illinois        NaN
# dtype: float64

# %%
pd.isna(obj5)
# Out:
# colorado     True
# Nyc         False
# Georgia      True
# illinois     True
# dtype: bool

# %%
pd.notna(obj5)
# Out:
# colorado    False
# Nyc          True
# Georgia     False
# illinois    False
# dtype: bool

# %%
obj4+obj5
# Out:
# Colorado        NaN
# Georgia         NaN
# Gregoria        NaN
# Illinois        NaN
# Nyc         42000.0
# colorado        NaN
# illinois        NaN
# dtype: float64

# %%
obj5.name ="Population"

# %%
obj5.index
# Out:
# Index(['colorado', 'Nyc', 'Georgia', 'illinois'], dtype='object')

# %%
obj.index= ['Bob','Jenifer','kat','Hailey']
obj
# Out:
# Bob        2
# Jenifer    7
# kat       -5
# Hailey    -3
# dtype: int64

# %% [markdown]
# # **DataFrame**

# %%
data={"state":["Iowa","Iowa","Iowa","NYC","NYC","NYC"],
      "Year" :[2000,2005,2008,2010,2015,2020],
      "Population":[2.4,5.7,5.9,6.1,None,8.1]}
frame=pd.DataFrame(data)
frame
# Out:
#   state  Year  Population
# 0  Iowa  2000         2.4
# 1  Iowa  2005         5.7
# 2  Iowa  2008         5.9
# 3   NYC  2010         6.1
# 4   NYC  2015         NaN
# 5   NYC  2020         8.1

# %%
frame.head(2)
# Out:
#   state  Year  Population
# 0  Iowa  2000         2.4
# 1  Iowa  2005         5.7

# %%
frame.tail(3)
# Out:
#   state  Year  Population
# 3   NYC  2010         6.1
# 4   NYC  2015         NaN
# 5   NYC  2020         8.1

# %%
frame.sample(4)
# Out:
#   state  Year  Population
# 1  Iowa  2005         5.7
# 2  Iowa  2008         5.9
# 4   NYC  2015         NaN
# 3   NYC  2010         6.1

# %%
pd.DataFrame(data,columns=["Year","state","Population"])
# Out:
#    Year state  Population
# 0  2000  Iowa         2.4
# 1  2005  Iowa         5.7
# 2  2008  Iowa         5.9
# 3  2010   NYC         6.1
# 4  2015   NYC         NaN
# 5  2020   NYC         8.1

# %%
frame2=pd.DataFrame(data,columns=["Year","state","Population","debt"])
frame2
# Out:
#    Year state  Population debt
# 0  2000  Iowa         2.4  NaN
# 1  2005  Iowa         5.7  NaN
# 2  2008  Iowa         5.9  NaN
# 3  2010   NYC         6.1  NaN
# 4  2015   NYC         NaN  NaN
# 5  2020   NYC         8.1  NaN

# %%
frame2.columns
# Out:
# Index(['Year', 'state', 'Population', 'debt'], dtype='object')

# %%
frame2.state
# Out:
# 0    Iowa
# 1    Iowa
# 2    Iowa
# 3     NYC
# 4     NYC
# 5     NYC
# Name: state, dtype: object

# %%
frame2.loc[1:3]
# Out:
#    Year state  Population debt
# 1  2005  Iowa         5.7  NaN
# 2  2008  Iowa         5.9  NaN
# 3  2010   NYC         6.1  NaN

# %%
frame2.iloc[1:3]
# Out:
#    Year state  Population debt
# 1  2005  Iowa         5.7  NaN
# 2  2008  Iowa         5.9  NaN

# %%
frame2["debt"] = 9.7
frame2
# Out:
#    Year state  Population  debt
# 0  2000  Iowa         2.4   9.7
# 1  2005  Iowa         5.7   9.7
# 2  2008  Iowa         5.9   9.7
# 3  2010   NYC         6.1   9.7
# 4  2015   NYC         NaN   9.7
# 5  2020   NYC         8.1   9.7

# %%
import numpy as np
frame2["debt"]=np.arange(6.0)
frame2
# Out:
#    Year state  Population  debt
# 0  2000  Iowa         2.4   0.0
# 1  2005  Iowa         5.7   1.0
# 2  2008  Iowa         5.9   2.0
# 3  2010   NYC         6.1   3.0
# 4  2015   NYC         NaN   4.0
# 5  2020   NYC         8.1   5.0

# %%
del frame2["Year"]
frame2
# Out:
#   state  Population  debt
# 0  Iowa         2.4   0.0
# 1  Iowa         5.7   1.0
# 2  Iowa         5.9   2.0
# 3   NYC         6.1   3.0
# 4   NYC         NaN   4.0
# 5   NYC         8.1   5.0

# %%
populations={"Rhode":{2000:1.5,2002:3.6,2005:8.9,2009:10.0},
             "Chicago":{2002:3.5 , 2001:5.3}}

frame3=pd.DataFrame(populations)
frame3
# Out:
#       Rhode  Chicago
# 2000    1.5      NaN
# 2002    3.6      3.5
# 2005    8.9      NaN
# 2009   10.0      NaN
# 2001    NaN      5.3

# %%
frame3.index.name="Year"
frame3
# Out:
#       Rhode  Chicago
# Year
# 2000    1.5      NaN
# 2002    3.6      3.5
# 2005    8.9      NaN
# 2009   10.0      NaN
# 2001    NaN      5.3

# %%
frame3.columns.name="state"
frame3
# Out:
# state  Rhode  Chicago
# Year
# 2000     1.5      NaN
# 2002     3.6      3.5
# 2005     8.9      NaN
# 2009    10.0      NaN
# 2001     NaN      5.3

# %%
frame3.to_numpy()
# Out:
# array([[ 1.5,  nan],
#        [ 3.6,  3.5],
#        [ 8.9,  nan],
#        [10. ,  nan],
#        [ nan,  5.3]])

# %% [markdown]
# # **Indexing**

# %%
import numpy as np
obj=pd.Series(np.arange(3),index=["a","b","c"])
index=obj.index
index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
index[1:]
# Out:
# Index(['b', 'c'], dtype='object')

# %% [markdown]
# index objects are immutable and thus cann't be modified by user

# %%
lables=pd.Index(np.arange(3))
lables
# Out:
# Int64Index([0, 1, 2], dtype='int64')

# %%
obj2=pd.Series([1.5,-2.5,0] ,index=lables)
obj2
# Out:
# 0    1.5
# 1   -2.5
# 2    0.0
# dtype: float64

# %%
obj2.index is lables
obj2
# Out:
# 0    1.5
# 1   -2.5
# 2    0.0
# dtype: float64

# %%
populations={"Idaho":{2000:2.5,2005:4.0,2009:8.2},
             "Virginia":{2000:3.6,2005:4.7,2009:6.8}}
frame3=pd.DataFrame(populations)
frame3
# Out:
#       Idaho  Virginia
# 2000    2.5       3.6
# 2005    4.0       4.7
# 2009    8.2       6.8

# %%
frame3.columns
# Out:
# Index(['Idaho', 'Virginia'], dtype='object')

# %%
"Idaho" in frame3.columns
# Out:
# True

# %%
2005 in frame3.index
# Out:
# True

# %% [markdown]
# # **Essential Funtionality**

# %%
obj=pd.Series([2,6.5,1.8,7.7] ,index=["b","a","c","d"])
obj
# Out:
# b    2.0
# a    6.5
# c    1.8
# d    7.7
# dtype: float64

# %%
obj2=obj.reindex(["a","b","c","d"])
obj2
# Out:
# a    6.5
# b    2.0
# c    1.8
# d    7.7
# dtype: float64

# %%
obj3=pd.Series(["pink","teal","Black","blue"],index=[1,2,3,5])
obj3
# Out:
# 1     pink
# 2     teal
# 3    Black
# 5     blue
# dtype: object

# %%
frame=pd.DataFrame(np.arange(9).reshape((3,3)),index=["a","b","c"],columns=["NYC","Carolina","Dakota"])
frame
# Out:
#    NYC  Carolina  Dakota
# a    0         1       2
# b    3         4       5
# c    6         7       8

# %%
frame2=frame.reindex(index=["a","b","c"])
frame2
# Out:
#    NYC  Carolina  Dakota
# a    0         1       2
# b    3         4       5
# c    6         7       8

# %%
states=["NYC","Dakota","Carolina"]
frame.reindex(columns=states)
# Out:
#    NYC  Dakota  Carolina
# a    0       2         1
# b    3       5         4
# c    6       8         7

# %%
obj=pd.Series(np.arange(5.),index=["a","b","c","d","e"])
obj
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# e    4.0
# dtype: float64

# %%
new_obj=obj.drop("c")
new_obj
# Out:
# b    2.0
# a    6.5
# d    7.7
# dtype: float64

# %%
obj.drop(["c","a"])
# Out:
# b    2.0
# d    7.7
# dtype: float64

# %%
data=pd.DataFrame(np.arange(16).reshape((4,4)),index=["a","b","c","d"],columns=["NYC","Carolina","Dakota","Utah"])
data
# Out:
#    NYC  Carolina  Dakota  Utah
# a    0         1       2     3
# b    4         5       6     7
# c    8         9      10    11
# d   12        13      14    15

# %%
data2= data.drop(index=["a","b"])
data2
# Out:
#    NYC  Carolina  Dakota  Utah
# c    8         9      10    11
# d   12        13      14    15

# %%
data.drop(columns=["Utah"])
# Out:
#    NYC  Carolina  Dakota
# a    0         1       2
# b    4         5       6
# c    8         9      10
# d   12        13      14

# %%
data.drop(columns="Utah",axis=1)
# Out:
#    NYC  Carolina  Dakota
# a    0         1       2
# b    4         5       6
# c    8         9      10
# d   12        13      14

# %%
data.drop(columns="NYC",axis=0)
# Out:
#    Carolina  Dakota  Utah
# a         1       2     3
# b         5       6     7
# c         9      10    11
# d        13      14    15

# %%
obj=pd.Series(np.arange(4),index=["x","y","z","x0"])
obj
# Out:
# x     0
# y     1
# z     2
# x0    3
# dtype: int64

# %%
obj["x"]
# Out:
# 0

# %%
obj[1:4]
# Out:
# y     1
# z     2
# x0    3
# dtype: int64

# %%
obj[obj>2]
# Out:
# x0    3
# dtype: int64

# %%
obj.loc[["x","y","z"]]
# Out:
# x    0
# y    1
# z    2
# dtype: int64
